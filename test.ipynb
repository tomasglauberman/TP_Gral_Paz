# %%
import simulator as sim
from AGP import AGP
import numpy as np
import matplotlib.pyplot as plt

# %%
agp = AGP(20)
simulation = sim.PathSimulation(10, agp, 0.1)
simulation.randomize_start()
simulation.plot()

# %%
np.random.rand(2)
# Out:
# array([0.88062467, 0.73474094])
