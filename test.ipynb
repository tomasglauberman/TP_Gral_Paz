# %%
from simulator import PathSimulation
from AGP import AGP
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.normal(90, 10, 1)[0]
# Out:
# 94.40356813844652

# %%
def acc_rate(x):
    if x > 120 or x<5:
        return 0.05
    return -9.75e-5 * (x**2) + 0.0117 * x - 0.05

# %%
space = np.linspace(0, 120, 1000)
plt.plot(space, [acc_rate(x) for x in space])
